# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
# YOUR CODE HERE
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    # YOUR CODE HERE
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        # YOUR CODE HERE
        cities.append(city)

# Print the city count to confirm sufficient count
# YOUR CODE HERE
print(len(cities))
# Out:
# 778

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # YOUR CODE HERE       
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        wind_speed = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_describe = city_weather["weather"][0]["description"]
        # Append the city information into the city_data list
        # YOUR CODE HERE
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": wind_speed,
                          "Current Description": weather_describe})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | bredasdorp
# Processing Record 3 of Set 1 | erenhot
# Processing Record 4 of Set 1 | deputatskiy
# Processing Record 5 of Set 1 | bambanglipuro
# Processing Record 6 of Set 1 | nikolskoye
# Processing Record 7 of Set 1 | tuatapere
# Processing Record 8 of Set 1 | luderitz
# Processing Record 9 of Set 1 | maple creek
# Processing Record 10 of Set 1 | lenger
# Processing Record 11 of Set 1 | maniwaki
# Processing Record 12 of Set 1 | dalbandin
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | nanortalik
# Processing Record 16 of Set 1 | carnarvon
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | tazovskiy
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | tanete
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | ejura
# Processing Record 23 of Set 1 | bluff
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | brae
# Processing Record 26 of Set 1 | resplendor
# Processing Record 27 of Set 1 | longyearbyen
# Processing Record 28 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 1 | norman wells
# Processing Record 30 of Set 1 | sola
# Processing Record 31 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 1 | ryabovo
# Processing Record 33 of Set 1 | saint anthony
# Processing Record 34 of Set 1 | saskylakh
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | antibes
# Processing Record 37 of Set 1 | kavaratti
# Processing Record 38 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 1 | kholtoson
# Processing Record 40 of Set 1 | torbay
# Processing Record 41 of Set 1 | berlevag
# Processing Record 42 of Set 1 | george town
# Processing Record 43 of Set 1 | mocuba
# Processing Record 44 of Set 1 | mataura
# Processing Record 45 of Set 1 | provideniya
# Processing Record 46 of Set 1 | ancud
# Processing Record 47 of Set 1 | mar del plata
# Processing Record 48 of Set 1 | novikovo
# Processing Record 49 of Set 1 | carepa
# Processing Record 50 of Set 1 | kavieng
# Processing Record 1 of Set 2 | college
# Processing Record 2 of Set 2 | qaanaaq
# Processing Record 3 of Set 2 | punta arenas
# Processing Record 4 of Set 2 | butaritari
# Processing Record 5 of Set 2 | sulangan
# Processing Record 6 of Set 2 | cidreira
# Processing Record 7 of Set 2 | faya
# Processing Record 8 of Set 2 | port alfred
# Processing Record 9 of Set 2 | kununurra
# Processing Record 10 of Set 2 | esperance
# Processing Record 11 of Set 2 | thompson
# Processing Record 12 of Set 2 | bilibino
# Processing Record 13 of Set 2 | severo-kurilsk
# Processing Record 14 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 2 | zomin
# Processing Record 16 of Set 2 | healdsburg
# Processing Record 17 of Set 2 | maldonado
# Processing Record 18 of Set 2 | lebu
# Processing Record 19 of Set 2 | hounde
# Processing Record 20 of Set 2 | cherskiy
# Processing Record 21 of Set 2 | vaini
# Processing Record 22 of Set 2 | khatanga
# Processing Record 23 of Set 2 | pangnirtung
# Processing Record 24 of Set 2 | maragogi
# Processing Record 25 of Set 2 | kapit
# Processing Record 26 of Set 2 | urucara
# Processing Record 27 of Set 2 | hatillo
# Processing Record 28 of Set 2 | salalah
# Processing Record 29 of Set 2 | kapaa
# Processing Record 30 of Set 2 | vangaindrano
# Processing Record 31 of Set 2 | coquimbo
# Processing Record 32 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 33 of Set 2 | albany
# Processing Record 34 of Set 2 | bardiyah
# Processing Record 35 of Set 2 | kruisfontein
# Processing Record 36 of Set 2 | tiarei
# Processing Record 37 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 2 | whyalla
# Processing Record 39 of Set 2 | bani walid
# Processing Record 40 of Set 2 | atuona
# Processing Record 41 of Set 2 | laguna
# Processing Record 42 of Set 2 | hami
# Processing Record 43 of Set 2 | sussex
# Processing Record 44 of Set 2 | katsuura
# Processing Record 45 of Set 2 | dauphin
# Processing Record 46 of Set 2 | tuktoyaktuk
# Processing Record 47 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 48 of Set 2 | arraial do cabo
# Processing Record 49 of Set 2 | parras
# City not found. Skipping...
# Processing Record 50 of Set 2 | axim
# Processing Record 1 of Set 3 | fare
# Processing Record 2 of Set 3 | pangody
# Processing Record 3 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 3 | paamiut
# Processing Record 5 of Set 3 | inongo
# Processing Record 6 of Set 3 | tual
# Processing Record 7 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 3 | salina
# Processing Record 9 of Set 3 | odesa
# Processing Record 10 of Set 3 | rio grande
# Processing Record 11 of Set 3 | hasaki
# Processing Record 12 of Set 3 | ishigaki
# Processing Record 13 of Set 3 | aksaray
# Processing Record 14 of Set 3 | new norfolk
# Processing Record 15 of Set 3 | mandurah
# Processing Record 16 of Set 3 | tiksi
# Processing Record 17 of Set 3 | atherton
# Processing Record 18 of Set 3 | fortuna
# Processing Record 19 of Set 3 | antalaha
# Processing Record 20 of Set 3 | shebunino
# Processing Record 21 of Set 3 | kantunilkin
# Processing Record 22 of Set 3 | marystown
# Processing Record 23 of Set 3 | ponta do sol
# Processing Record 24 of Set 3 | tasiilaq
# Processing Record 25 of Set 3 | egvekinot
# Processing Record 26 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 3 | lompoc
# Processing Record 28 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 3 | saldanha
# Processing Record 30 of Set 3 | basco
# Processing Record 31 of Set 3 | hilo
# Processing Record 32 of Set 3 | geraldton
# Processing Record 33 of Set 3 | santarem
# Processing Record 34 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 3 | mumford
# Processing Record 36 of Set 3 | bida
# Processing Record 37 of Set 3 | bathsheba
# Processing Record 38 of Set 3 | kiruna
# Processing Record 39 of Set 3 | xining
# Processing Record 40 of Set 3 | yerkoy
# Processing Record 41 of Set 3 | soritor
# Processing Record 42 of Set 3 | itoman
# Processing Record 43 of Set 3 | rio gallegos
# Processing Record 44 of Set 3 | ust-kut
# Processing Record 45 of Set 3 | bethel
# Processing Record 46 of Set 3 | pueblo nuevo
# Processing Record 47 of Set 3 | kemijarvi
# Processing Record 48 of Set 3 | georgetown
# Processing Record 49 of Set 3 | ryotsu
# Processing Record 50 of Set 3 | souillac
# Processing Record 1 of Set 4 | san quintin
# Processing Record 2 of Set 4 | port lincoln
# Processing Record 3 of Set 4 | coahuayana
# Processing Record 4 of Set 4 | sedelnikovo
# City not found. Skipping...
# Processing Record 5 of Set 4 | sao filipe
# Processing Record 6 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 4 | teya
# Processing Record 8 of Set 4 | cururupu
# Processing Record 9 of Set 4 | sesimbra
# Processing Record 10 of Set 4 | makinsk
# Processing Record 11 of Set 4 | tomatlan
# Processing Record 12 of Set 4 | japura
# Processing Record 13 of Set 4 | klaksvik
# Processing Record 14 of Set 4 | faanui
# Processing Record 15 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 4 | west richland
# Processing Record 17 of Set 4 | tongzi
# Processing Record 18 of Set 4 | ilhabela
# Processing Record 19 of Set 4 | polunochnoye
# Processing Record 20 of Set 4 | chuy
# Processing Record 21 of Set 4 | nchelenge
# Processing Record 22 of Set 4 | shumskiy
# Processing Record 23 of Set 4 | tilichiki
# Processing Record 24 of Set 4 | juneau
# Processing Record 25 of Set 4 | port elizabeth
# Processing Record 26 of Set 4 | barrow
# Processing Record 27 of Set 4 | san patricio
# Processing Record 28 of Set 4 | ribeira grande
# Processing Record 29 of Set 4 | nouadhibou
# Processing Record 30 of Set 4 | karratha
# Processing Record 31 of Set 4 | dujuma
# City not found. Skipping...
# Processing Record 32 of Set 4 | iqaluit
# Processing Record 33 of Set 4 | kaabong
# Processing Record 34 of Set 4 | baryshivka
# Processing Record 35 of Set 4 | manuel doblado
# City not found. Skipping...
# Processing Record 36 of Set 4 | manta
# Processing Record 37 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 4 | hay river
# Processing Record 39 of Set 4 | darhan
# Processing Record 40 of Set 4 | sinnamary
# Processing Record 41 of Set 4 | ilulissat
# Processing Record 42 of Set 4 | saint-philippe
# Processing Record 43 of Set 4 | roald
# Processing Record 44 of Set 4 | hithadhoo
# Processing Record 45 of Set 4 | east london
# Processing Record 46 of Set 4 | kimbe
# Processing Record 47 of Set 4 | oussouye
# Processing Record 48 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 49 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 4 | hobart
# Processing Record 1 of Set 5 | port blair
# Processing Record 2 of Set 5 | kaitangata
# Processing Record 3 of Set 5 | qaqortoq
# Processing Record 4 of Set 5 | yellowknife
# Processing Record 5 of Set 5 | marathokambos
# City not found. Skipping...
# Processing Record 6 of Set 5 | alice springs
# Processing Record 7 of Set 5 | fort nelson
# Processing Record 8 of Set 5 | olga
# Processing Record 9 of Set 5 | balkhash
# Processing Record 10 of Set 5 | willowmore
# Processing Record 11 of Set 5 | altamira
# Processing Record 12 of Set 5 | mamontovo
# Processing Record 13 of Set 5 | talnakh
# Processing Record 14 of Set 5 | aykhal
# Processing Record 15 of Set 5 | gumdag
# Processing Record 16 of Set 5 | ahuimanu
# Processing Record 17 of Set 5 | dikson
# Processing Record 18 of Set 5 | storforshei
# Processing Record 19 of Set 5 | kaeo
# Processing Record 20 of Set 5 | sabha
# Processing Record 21 of Set 5 | heihe
# Processing Record 22 of Set 5 | amapa
# Processing Record 23 of Set 5 | isangel
# Processing Record 24 of Set 5 | chokurdakh
# Processing Record 25 of Set 5 | pisco
# Processing Record 26 of Set 5 | saint-francois
# Processing Record 27 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 5 | khuzhir
# Processing Record 29 of Set 5 | villanueva
# Processing Record 30 of Set 5 | lavrentiya
# Processing Record 31 of Set 5 | kamaishi
# Processing Record 32 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 33 of Set 5 | lima
# Processing Record 34 of Set 5 | angoche
# Processing Record 35 of Set 5 | morondava
# Processing Record 36 of Set 5 | aranos
# Processing Record 37 of Set 5 | manzanillo
# Processing Record 38 of Set 5 | yulara
# Processing Record 39 of Set 5 | bambous virieux
# Processing Record 40 of Set 5 | constantine
# Processing Record 41 of Set 5 | vao
# Processing Record 42 of Set 5 | vostok
# Processing Record 43 of Set 5 | roma
# Processing Record 44 of Set 5 | seymchan
# Processing Record 45 of Set 5 | chapais
# Processing Record 46 of Set 5 | mountain home
# Processing Record 47 of Set 5 | anyksciai
# Processing Record 48 of Set 5 | sakaiminato
# Processing Record 49 of Set 5 | gizo
# Processing Record 50 of Set 5 | ryomgard
# Processing Record 1 of Set 6 | sumter
# Processing Record 2 of Set 6 | narsaq
# Processing Record 3 of Set 6 | waslala
# Processing Record 4 of Set 6 | rokytne
# Processing Record 5 of Set 6 | paragominas
# Processing Record 6 of Set 6 | bengkulu
# Processing Record 7 of Set 6 | topolobampo
# Processing Record 8 of Set 6 | verkhniye sergi
# Processing Record 9 of Set 6 | tuxpan
# Processing Record 10 of Set 6 | lucapa
# Processing Record 11 of Set 6 | vrangel
# Processing Record 12 of Set 6 | airai
# Processing Record 13 of Set 6 | upernavik
# Processing Record 14 of Set 6 | quesnel
# Processing Record 15 of Set 6 | guerrero negro
# Processing Record 16 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 6 | masvingo
# Processing Record 18 of Set 6 | mandiana
# Processing Record 19 of Set 6 | erzin
# Processing Record 20 of Set 6 | zabinka
# City not found. Skipping...
# Processing Record 21 of Set 6 | sitka
# Processing Record 22 of Set 6 | cabo san lucas
# Processing Record 23 of Set 6 | rehoboth
# Processing Record 24 of Set 6 | canavieiras
# Processing Record 25 of Set 6 | sistranda
# Processing Record 26 of Set 6 | pasighat
# Processing Record 27 of Set 6 | phaltan
# Processing Record 28 of Set 6 | sayat
# Processing Record 29 of Set 6 | mudigere
# Processing Record 30 of Set 6 | sande
# Processing Record 31 of Set 6 | huancabamba
# Processing Record 32 of Set 6 | steinbach
# Processing Record 33 of Set 6 | krasnoselkup
# Processing Record 34 of Set 6 | tatarsk
# Processing Record 35 of Set 6 | castro
# Processing Record 36 of Set 6 | tsaratanana
# Processing Record 37 of Set 6 | vila velha
# Processing Record 38 of Set 6 | bairiki
# Processing Record 39 of Set 6 | te anau
# Processing Record 40 of Set 6 | dingle
# Processing Record 41 of Set 6 | berwick
# Processing Record 42 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 6 | ratnagiri
# Processing Record 44 of Set 6 | teguise
# Processing Record 45 of Set 6 | udachnyy
# Processing Record 46 of Set 6 | plettenberg bay
# Processing Record 47 of Set 6 | portland
# Processing Record 48 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 6 | nemuro
# Processing Record 50 of Set 6 | namibe
# Processing Record 1 of Set 7 | northam
# Processing Record 2 of Set 7 | aleppo
# Processing Record 3 of Set 7 | kindersley
# Processing Record 4 of Set 7 | sao paulo de olivenca
# Processing Record 5 of Set 7 | ketchikan
# Processing Record 6 of Set 7 | kirakira
# Processing Record 7 of Set 7 | hun
# Processing Record 8 of Set 7 | harper
# Processing Record 9 of Set 7 | llanes
# Processing Record 10 of Set 7 | mahebourg
# Processing Record 11 of Set 7 | nogliki
# Processing Record 12 of Set 7 | lata
# Processing Record 13 of Set 7 | bandarbeyla
# Processing Record 14 of Set 7 | agva
# City not found. Skipping...
# Processing Record 15 of Set 7 | waterloo
# Processing Record 16 of Set 7 | troitskoye
# Processing Record 17 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 18 of Set 7 | burns lake
# Processing Record 19 of Set 7 | pevek
# Processing Record 20 of Set 7 | beisfjord
# Processing Record 21 of Set 7 | znamenskoye
# Processing Record 22 of Set 7 | wagar
# Processing Record 23 of Set 7 | saint-pierre
# Processing Record 24 of Set 7 | henties bay
# Processing Record 25 of Set 7 | shaunavon
# Processing Record 26 of Set 7 | kaura namoda
# Processing Record 27 of Set 7 | kahului
# Processing Record 28 of Set 7 | kokoda
# Processing Record 29 of Set 7 | ayan
# Processing Record 30 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 7 | lugde
# Processing Record 32 of Set 7 | lazurne
# Processing Record 33 of Set 7 | huambo
# Processing Record 34 of Set 7 | manzhouli
# Processing Record 35 of Set 7 | margate
# Processing Record 36 of Set 7 | touros
# Processing Record 37 of Set 7 | sangre grande
# Processing Record 38 of Set 7 | tosagua
# Processing Record 39 of Set 7 | la paz
# Processing Record 40 of Set 7 | necochea
# Processing Record 41 of Set 7 | port hedland
# Processing Record 42 of Set 7 | virginia beach
# Processing Record 43 of Set 7 | port augusta
# Processing Record 44 of Set 7 | lethem
# Processing Record 45 of Set 7 | hanmer springs
# Processing Record 46 of Set 7 | sao caetano de odivelas
# Processing Record 47 of Set 7 | vanimo
# Processing Record 48 of Set 7 | dingli
# Processing Record 49 of Set 7 | cricau
# Processing Record 50 of Set 7 | takab
# Processing Record 1 of Set 8 | chakrata
# Processing Record 2 of Set 8 | puerto quijarro
# Processing Record 3 of Set 8 | jutai
# Processing Record 4 of Set 8 | bodden town
# Processing Record 5 of Set 8 | paraiso
# Processing Record 6 of Set 8 | campo verde
# Processing Record 7 of Set 8 | north bend
# Processing Record 8 of Set 8 | grindavik
# Processing Record 9 of Set 8 | wanaka
# Processing Record 10 of Set 8 | muros
# Processing Record 11 of Set 8 | san
# Processing Record 12 of Set 8 | nishihara
# Processing Record 13 of Set 8 | magadan
# Processing Record 14 of Set 8 | blagoyevo
# Processing Record 15 of Set 8 | nizwa
# Processing Record 16 of Set 8 | khandyga
# Processing Record 17 of Set 8 | kodiak
# Processing Record 18 of Set 8 | manacapuru
# Processing Record 19 of Set 8 | jackson
# Processing Record 20 of Set 8 | mishkino
# Processing Record 21 of Set 8 | marawi
# Processing Record 22 of Set 8 | san cristobal
# Processing Record 23 of Set 8 | coihaique
# Processing Record 24 of Set 8 | ponta delgada
# Processing Record 25 of Set 8 | mapiri
# Processing Record 26 of Set 8 | toora-khem
# Processing Record 27 of Set 8 | makakilo city
# Processing Record 28 of Set 8 | rawah
# Processing Record 29 of Set 8 | burgeo
# Processing Record 30 of Set 8 | amsterdam
# Processing Record 31 of Set 8 | baruun-urt
# Processing Record 32 of Set 8 | santa fe
# Processing Record 33 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 34 of Set 8 | lagoa
# Processing Record 35 of Set 8 | egyek
# Processing Record 36 of Set 8 | constitucion
# Processing Record 37 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 8 | pedernales
# Processing Record 39 of Set 8 | puyallup
# Processing Record 40 of Set 8 | vestmannaeyjar
# Processing Record 41 of Set 8 | alexandria
# Processing Record 42 of Set 8 | sombrio
# Processing Record 43 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 44 of Set 8 | lakes entrance
# Processing Record 45 of Set 8 | skjervoy
# Processing Record 46 of Set 8 | hofn
# Processing Record 47 of Set 8 | numan
# Processing Record 48 of Set 8 | pare
# Processing Record 49 of Set 8 | banjar
# Processing Record 50 of Set 8 | isla vista
# Processing Record 1 of Set 9 | hangu
# Processing Record 2 of Set 9 | laje
# Processing Record 3 of Set 9 | teahupoo
# Processing Record 4 of Set 9 | mount gambier
# Processing Record 5 of Set 9 | vila franca do campo
# Processing Record 6 of Set 9 | chabahar
# Processing Record 7 of Set 9 | sajanan
# Processing Record 8 of Set 9 | tigil
# Processing Record 9 of Set 9 | gat
# Processing Record 10 of Set 9 | el alto
# Processing Record 11 of Set 9 | kautokeino
# Processing Record 12 of Set 9 | olbia
# Processing Record 13 of Set 9 | gondanglegi
# Processing Record 14 of Set 9 | smithers
# Processing Record 15 of Set 9 | payakumbuh
# Processing Record 16 of Set 9 | balagon
# Processing Record 17 of Set 9 | reconquista
# Processing Record 18 of Set 9 | taksimo
# Processing Record 19 of Set 9 | port moresby
# Processing Record 20 of Set 9 | lavumisa
# Processing Record 21 of Set 9 | noumea
# Processing Record 22 of Set 9 | cuxhaven
# Processing Record 23 of Set 9 | sorland
# Processing Record 24 of Set 9 | komsomolskiy
# Processing Record 25 of Set 9 | altay
# Processing Record 26 of Set 9 | eyrarbakki
# Processing Record 27 of Set 9 | high level
# Processing Record 28 of Set 9 | mangai
# Processing Record 29 of Set 9 | belaya gora
# Processing Record 30 of Set 9 | karakol
# Processing Record 31 of Set 9 | mercedes
# Processing Record 32 of Set 9 | awbari
# Processing Record 33 of Set 9 | bonavista
# Processing Record 34 of Set 9 | jibuti
# Processing Record 35 of Set 9 | zabid
# Processing Record 36 of Set 9 | saint george
# Processing Record 37 of Set 9 | neuquen
# Processing Record 38 of Set 9 | nara
# Processing Record 39 of Set 9 | nesbyen
# Processing Record 40 of Set 9 | mecca
# Processing Record 41 of Set 9 | salur
# Processing Record 42 of Set 9 | chernyshevskiy
# Processing Record 43 of Set 9 | maumere
# Processing Record 44 of Set 9 | rockport
# Processing Record 45 of Set 9 | karlskoga
# Processing Record 46 of Set 9 | hooksett
# Processing Record 47 of Set 9 | nome
# Processing Record 48 of Set 9 | asayita
# City not found. Skipping...
# Processing Record 49 of Set 9 | ixtapa
# Processing Record 50 of Set 9 | bondo
# Processing Record 1 of Set 10 | solsvik
# City not found. Skipping...
# Processing Record 2 of Set 10 | clyde river
# Processing Record 3 of Set 10 | meulaboh
# Processing Record 4 of Set 10 | puerto santander
# Processing Record 5 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 6 of Set 10 | santa rosa
# Processing Record 7 of Set 10 | hongan
# City not found. Skipping...
# Processing Record 8 of Set 10 | tarakan
# Processing Record 9 of Set 10 | nuuk
# Processing Record 10 of Set 10 | kalmunai
# Processing Record 11 of Set 10 | maniitsoq
# Processing Record 12 of Set 10 | kissidougou
# Processing Record 13 of Set 10 | lackawanna
# Processing Record 14 of Set 10 | jacareacanga
# Processing Record 15 of Set 10 | pacific grove
# Processing Record 16 of Set 10 | mukhen
# Processing Record 17 of Set 10 | victoria
# Processing Record 18 of Set 10 | ambon
# Processing Record 19 of Set 10 | padang
# Processing Record 20 of Set 10 | bilma
# Processing Record 21 of Set 10 | anadyr
# Processing Record 22 of Set 10 | maceio
# Processing Record 23 of Set 10 | raudeberg
# Processing Record 24 of Set 10 | obo
# Processing Record 25 of Set 10 | san jeronimo
# Processing Record 26 of Set 10 | oeiras
# Processing Record 27 of Set 10 | san julian
# Processing Record 28 of Set 10 | tura
# Processing Record 29 of Set 10 | fairborn
# Processing Record 30 of Set 10 | hovd
# Processing Record 31 of Set 10 | port hardy
# Processing Record 32 of Set 10 | huaiyin
# Processing Record 33 of Set 10 | yarkovo
# Processing Record 34 of Set 10 | matata
# Processing Record 35 of Set 10 | iquique
# Processing Record 36 of Set 10 | labuhan
# Processing Record 37 of Set 10 | shihezi
# Processing Record 38 of Set 10 | horki
# Processing Record 39 of Set 10 | otradnoye
# Processing Record 40 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 41 of Set 10 | quimper
# Processing Record 42 of Set 10 | baboua
# City not found. Skipping...
# Processing Record 43 of Set 10 | tromso
# Processing Record 44 of Set 10 | bud
# Processing Record 45 of Set 10 | adrar
# Processing Record 46 of Set 10 | santiago de cuba
# Processing Record 47 of Set 10 | gulshat
# City not found. Skipping...
# Processing Record 48 of Set 10 | korla
# Processing Record 49 of Set 10 | pandan niog
# Processing Record 50 of Set 10 | rodrigues alves
# Processing Record 1 of Set 11 | charleston
# Processing Record 2 of Set 11 | greenville
# Processing Record 3 of Set 11 | robertsport
# Processing Record 4 of Set 11 | suzhou
# Processing Record 5 of Set 11 | gweta
# Processing Record 6 of Set 11 | port shepstone
# Processing Record 7 of Set 11 | caravelas
# Processing Record 8 of Set 11 | liverpool
# Processing Record 9 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 10 of Set 11 | dera bugti
# Processing Record 11 of Set 11 | papara
# Processing Record 12 of Set 11 | derzhavinsk
# Processing Record 13 of Set 11 | alice town
# Processing Record 14 of Set 11 | westport
# Processing Record 15 of Set 11 | liuzhou
# Processing Record 16 of Set 11 | port macquarie
# Processing Record 17 of Set 11 | calvinia
# Processing Record 18 of Set 11 | kedrovyy
# Processing Record 19 of Set 11 | vicuna
# Processing Record 20 of Set 11 | malko tarnovo
# Processing Record 21 of Set 11 | labytnangi
# Processing Record 22 of Set 11 | treinta y tres
# Processing Record 23 of Set 11 | itabira
# Processing Record 24 of Set 11 | manokwari
# Processing Record 25 of Set 11 | srivardhan
# Processing Record 26 of Set 11 | primorsk
# Processing Record 27 of Set 11 | vieques
# Processing Record 28 of Set 11 | cockburn town
# Processing Record 29 of Set 11 | inhambane
# Processing Record 30 of Set 11 | jalaun
# Processing Record 31 of Set 11 | aklavik
# Processing Record 32 of Set 11 | manoharpur
# Processing Record 33 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 34 of Set 11 | kieta
# Processing Record 35 of Set 11 | csongrad
# Processing Record 36 of Set 11 | trinidad
# Processing Record 37 of Set 11 | ojinaga
# Processing Record 38 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 39 of Set 11 | tanggu
# Processing Record 40 of Set 11 | kishni
# Processing Record 41 of Set 11 | riyadh
# Processing Record 42 of Set 11 | ostrovnoy
# Processing Record 43 of Set 11 | manuk mangkaw
# Processing Record 44 of Set 11 | lasa
# Processing Record 45 of Set 11 | mandera
# Processing Record 46 of Set 11 | bodo
# Processing Record 47 of Set 11 | conde
# Processing Record 48 of Set 11 | paita
# Processing Record 49 of Set 11 | fengrun
# Processing Record 50 of Set 11 | praia
# Processing Record 1 of Set 12 | boyolangu
# Processing Record 2 of Set 12 | innisfail
# Processing Record 3 of Set 12 | hella
# Processing Record 4 of Set 12 | cairns
# Processing Record 5 of Set 12 | ornskoldsvik
# Processing Record 6 of Set 12 | villarrobledo
# Processing Record 7 of Set 12 | ballarat
# Processing Record 8 of Set 12 | chandbali
# Processing Record 9 of Set 12 | pontian kecil
# Processing Record 10 of Set 12 | camana
# Processing Record 11 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 12 | okhotsk
# Processing Record 13 of Set 12 | upington
# Processing Record 14 of Set 12 | grand gaube
# Processing Record 15 of Set 12 | bibiani
# Processing Record 16 of Set 12 | vung tau
# Processing Record 17 of Set 12 | shchelyayur
# City not found. Skipping...
# Processing Record 18 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 19 of Set 12 | ust-omchug
# Processing Record 20 of Set 12 | ust-kulom
# Processing Record 21 of Set 12 | vestmanna
# Processing Record 22 of Set 12 | uray
# Processing Record 23 of Set 12 | tynda
# Processing Record 24 of Set 12 | bakreswar
# Processing Record 25 of Set 12 | sambava
# Processing Record 26 of Set 12 | sumbawa
# City not found. Skipping...
# Processing Record 27 of Set 12 | jinchengjiang
# City not found. Skipping...
# Processing Record 28 of Set 12 | the valley
# Processing Record 29 of Set 12 | changtu
# Processing Record 30 of Set 12 | blackwater
# Processing Record 31 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 12 | aksu
# Processing Record 33 of Set 12 | fershampenuaz
# Processing Record 34 of Set 12 | camacari
# Processing Record 35 of Set 12 | dongsheng
# Processing Record 36 of Set 12 | jalu
# Processing Record 37 of Set 12 | samarai
# Processing Record 38 of Set 12 | leo
# Processing Record 39 of Set 12 | beloha
# Processing Record 40 of Set 12 | bosaso
# Processing Record 41 of Set 12 | mazagao
# Processing Record 42 of Set 12 | isla mujeres
# Processing Record 43 of Set 12 | salima
# Processing Record 44 of Set 12 | biak
# Processing Record 45 of Set 12 | praia da vitoria
# Processing Record 46 of Set 12 | bluefields
# Processing Record 47 of Set 12 | san felipe
# Processing Record 48 of Set 12 | namwala
# Processing Record 49 of Set 12 | zhigansk
# Processing Record 50 of Set 12 | la grande
# Processing Record 1 of Set 13 | gravdal
# Processing Record 2 of Set 13 | alofi
# Processing Record 3 of Set 13 | asau
# Processing Record 4 of Set 13 | naze
# Processing Record 5 of Set 13 | tay ninh
# Processing Record 6 of Set 13 | rawson
# Processing Record 7 of Set 13 | dickson
# Processing Record 8 of Set 13 | daru
# Processing Record 9 of Set 13 | bata
# Processing Record 10 of Set 13 | mtimbira
# Processing Record 11 of Set 13 | lodja
# Processing Record 12 of Set 13 | carmen
# Processing Record 13 of Set 13 | aguimes
# Processing Record 14 of Set 13 | kutum
# Processing Record 15 of Set 13 | jambi
# Processing Record 16 of Set 13 | corinto
# Processing Record 17 of Set 13 | venice
# Processing Record 18 of Set 13 | jablah
# Processing Record 19 of Set 13 | uige
# Processing Record 20 of Set 13 | celestun
# Processing Record 21 of Set 13 | barra dos coqueiros
# Processing Record 22 of Set 13 | perth
# Processing Record 23 of Set 13 | abong mbang
# Processing Record 24 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 25 of Set 13 | dali
# Processing Record 26 of Set 13 | cleveland
# Processing Record 27 of Set 13 | matara
# Processing Record 28 of Set 13 | buckeye
# Processing Record 29 of Set 13 | kondinskoye
# Processing Record 30 of Set 13 | haflong
# Processing Record 31 of Set 13 | linxia
# Processing Record 32 of Set 13 | avenal
# Processing Record 33 of Set 13 | nassau
# Processing Record 34 of Set 13 | gedo
# Processing Record 35 of Set 13 | kazerun
# Processing Record 36 of Set 13 | ryki
# Processing Record 37 of Set 13 | kokopo
# Processing Record 38 of Set 13 | la ronge
# Processing Record 39 of Set 13 | nelson bay
# Processing Record 40 of Set 13 | beringovskiy
# Processing Record 41 of Set 13 | cabedelo
# Processing Record 42 of Set 13 | red deer
# Processing Record 43 of Set 13 | tymovskoye
# Processing Record 44 of Set 13 | suzun
# Processing Record 45 of Set 13 | bac lieu
# Processing Record 46 of Set 13 | bengbu
# Processing Record 47 of Set 13 | yoichi
# Processing Record 48 of Set 13 | onguday
# Processing Record 49 of Set 13 | anito
# Processing Record 50 of Set 13 | beyneu
# Processing Record 1 of Set 14 | yarada
# Processing Record 2 of Set 14 | vardo
# Processing Record 3 of Set 14 | conceicao do araguaia
# Processing Record 4 of Set 14 | zaysan
# Processing Record 5 of Set 14 | huilong
# Processing Record 6 of Set 14 | carora
# Processing Record 7 of Set 14 | waitati
# Processing Record 8 of Set 14 | kamenka
# Processing Record 9 of Set 14 | dabakala
# Processing Record 10 of Set 14 | leningradskiy
# Processing Record 11 of Set 14 | calais
# Processing Record 12 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 13 of Set 14 | raniganj
# Processing Record 14 of Set 14 | agadez
# Processing Record 15 of Set 14 | alberton
# Processing Record 16 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 14 | half moon bay
# Processing Record 18 of Set 14 | methoni
# Processing Record 19 of Set 14 | tessalit
# Processing Record 20 of Set 14 | bairnsdale
# Processing Record 21 of Set 14 | barsovo
# Processing Record 22 of Set 14 | cap malheureux
# Processing Record 23 of Set 14 | bubaque
# Processing Record 24 of Set 14 | dipkarpaz
# City not found. Skipping...
# Processing Record 25 of Set 14 | todos santos
# Processing Record 26 of Set 14 | manhattan
# Processing Record 27 of Set 14 | moron
# Processing Record 28 of Set 14 | chimbote
# Processing Record 29 of Set 14 | goderich
# Processing Record 30 of Set 14 | hohhot
# Processing Record 31 of Set 14 | hualmay
# Processing Record 32 of Set 14 | monterey
# Processing Record 33 of Set 14 | panaba
# Processing Record 34 of Set 14 | dunedin
# Processing Record 35 of Set 14 | porto murtinho
# Processing Record 36 of Set 14 | fairbanks
# Processing Record 37 of Set 14 | buala
# Processing Record 38 of Set 14 | gazli
# Processing Record 39 of Set 14 | ballina
# Processing Record 40 of Set 14 | solnechnyy
# Processing Record 41 of Set 14 | mayo
# Processing Record 42 of Set 14 | nuevo progreso
# Processing Record 43 of Set 14 | keti bandar
# Processing Record 44 of Set 14 | gallup
# Processing Record 45 of Set 14 | popondetta
# Processing Record 46 of Set 14 | san agustin
# Processing Record 47 of Set 14 | taldan
# Processing Record 48 of Set 14 | chokwe
# Processing Record 49 of Set 14 | sur
# Processing Record 50 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 1 of Set 15 | aras
# Processing Record 2 of Set 15 | brahasesti
# Processing Record 3 of Set 15 | queimadas
# Processing Record 4 of Set 15 | silver city
# Processing Record 5 of Set 15 | damavand
# Processing Record 6 of Set 15 | yanam
# Processing Record 7 of Set 15 | walvis bay
# Processing Record 8 of Set 15 | de-kastri
# Processing Record 9 of Set 15 | coxim
# Processing Record 10 of Set 15 | dnipryany
# Processing Record 11 of Set 15 | jinchang
# Processing Record 12 of Set 15 | sioux lookout
# Processing Record 13 of Set 15 | mandalgovi
# Processing Record 14 of Set 15 | mulege
# Processing Record 15 of Set 15 | rivera
# Processing Record 16 of Set 15 | yumen
# Processing Record 17 of Set 15 | zachagansk
# City not found. Skipping...
# Processing Record 18 of Set 15 | nadym
# Processing Record 19 of Set 15 | lorengau
# Processing Record 20 of Set 15 | ugoofaaru
# Processing Record 21 of Set 15 | severnyy
# Processing Record 22 of Set 15 | icod de los vinos
# Processing Record 23 of Set 15 | acapulco
# Processing Record 24 of Set 15 | nador
# Processing Record 25 of Set 15 | nkhata bay
# Processing Record 26 of Set 15 | nyurba
# Processing Record 27 of Set 15 | boysun
# Processing Record 28 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 29 of Set 15 | luena
# Processing Record 30 of Set 15 | dabhol
# Processing Record 31 of Set 15 | privolnaya
# Processing Record 32 of Set 15 | bereda
# Processing Record 33 of Set 15 | trairi
# Processing Record 34 of Set 15 | ahipara
# Processing Record 35 of Set 15 | kawana waters
# City not found. Skipping...
# Processing Record 36 of Set 15 | pinkafeld
# Processing Record 37 of Set 15 | champerico
# Processing Record 38 of Set 15 | batagay
# Processing Record 39 of Set 15 | aflao
# Processing Record 40 of Set 15 | bayanday
# Processing Record 41 of Set 15 | bonham
# Processing Record 42 of Set 15 | ondjiva
# Processing Record 43 of Set 15 | krasnogorsk
# Processing Record 44 of Set 15 | severo-yeniseyskiy
# Processing Record 45 of Set 15 | sao miguel do araguaia
# Processing Record 46 of Set 15 | majene
# Processing Record 47 of Set 15 | salinopolis
# Processing Record 48 of Set 15 | maloy
# Processing Record 49 of Set 15 | bizhbulyak
# Processing Record 50 of Set 15 | qandala
# Processing Record 1 of Set 16 | koumac
# Processing Record 2 of Set 16 | bitung
# Processing Record 3 of Set 16 | miles city
# Processing Record 4 of Set 16 | churapcha
# Processing Record 5 of Set 16 | rosamorada
# Processing Record 6 of Set 16 | pemberton
# Processing Record 7 of Set 16 | alotau
# City not found. Skipping...
# Processing Record 8 of Set 16 | lupiro
# Processing Record 9 of Set 16 | marshfield
# Processing Record 10 of Set 16 | depok
# Processing Record 11 of Set 16 | olinda
# Processing Record 12 of Set 16 | loiza
# Processing Record 13 of Set 16 | san vicente
# Processing Record 14 of Set 16 | mayumba
# Processing Record 15 of Set 16 | malartic
# Processing Record 16 of Set 16 | caceres
# Processing Record 17 of Set 16 | novobureyskiy
# Processing Record 18 of Set 16 | priiskovyy
# Processing Record 19 of Set 16 | begun
# Processing Record 20 of Set 16 | eureka
# Processing Record 21 of Set 16 | santa rita
# Processing Record 22 of Set 16 | avera
# Processing Record 23 of Set 16 | elizabeth city
# Processing Record 24 of Set 16 | placerville
# Processing Record 25 of Set 16 | maryville
# Processing Record 26 of Set 16 | maun
# Processing Record 27 of Set 16 | minatitlan
# Processing Record 28 of Set 16 | kisangani
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 720

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Hermanus      ZA -34.4187   19.2345     63.81        95          81
# 1     Bredasdorp      ZA -34.5322   20.0403     60.06        96          90
# 2        Erenhot      CN  43.6475  111.9767     35.55        23           0
# 3    Deputatskiy      RU  69.3000  139.9000      4.96        94          94
# 4  Bambanglipuro      ID  -7.9500  110.2833     76.24        90         100
# 5     Nikolskoye      RU  59.7035   30.7861     49.91        82         100
# 6      Tuatapere      NZ -46.1333  167.6833     43.86        84          65
# 7       Luderitz      NA -26.6481   15.1594     61.00        78           0
# 8    Maple Creek      CA  49.9168 -109.4848     75.25        20           5
# 9         Lenger      KZ  42.1830   69.8839     49.44        81         100
#
#    Wind Speed Current Description
# 0        4.70       broken clouds
# 1        1.97     overcast clouds
# 2        8.99           clear sky
# 3        5.99     overcast clouds
# 4        4.81          light rain
# 5       11.21     overcast clouds
# 6        8.16       broken clouds
# 7        9.33           clear sky
# 8        9.22           clear sky
# 9        1.34     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE
city_data_reorder = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE
city_data_reDf = pd.DataFrame(columns=city_data_reorder)
for colume in city_data_reorder:
    city_data_reDf[colume] = city_data_df[colume]

# Display sample data
# YOUR CODE HERE
city_data_reDf
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Hermanus      ZA -34.4187   19.2345     63.81        95          81
# 1       Bredasdorp      ZA -34.5322   20.0403     60.06        96          90
# 2          Erenhot      CN  43.6475  111.9767     35.55        23           0
# 3      Deputatskiy      RU  69.3000  139.9000      4.96        94          94
# 4    Bambanglipuro      ID  -7.9500  110.2833     76.24        90         100
# ..             ...     ...      ...       ...       ...       ...         ...
# 715    Placerville      US  38.7296 -120.7986     78.78        43           0
# 716      Maryville      US  35.7565  -83.9705     67.06        47          20
# 717           Maun      BW -19.9833   23.4167     78.01        23          96
# 718     Minatitlan      MX  17.9833  -94.5167     82.49        89          75
# 719      Kisangani      CD   0.5167   25.2000     69.24        87          37
#
#      Wind Speed Current Description
# 0          4.70       broken clouds
# 1          1.97     overcast clouds
# 2          8.99           clear sky
# 3          5.99     overcast clouds
# 4          4.81          light rain
# ..          ...                 ...
# 715        4.61           clear sky
# 716       19.57          few clouds
# 717        3.09     overcast clouds
# 718        3.44       broken clouds
# 719        2.84    scattered clouds
#
# [720 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE
city_data_reDf.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE
file_name = 'WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
city_data_reDf.to_csv(file_name,index=False)
